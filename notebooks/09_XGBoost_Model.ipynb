# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import(
    f1_score,
    recall_score,
    accuracy_score,
    roc_auc_score,
    precision_score,
    confusion_matrix,
    classification_report
)
feature_dataset = pd.read_csv("../data/processed/feature_dataset.csv")
X = feature_dataset.drop("SepsisLabel", axis=1)
y = feature_dataset["SepsisLabel"]
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = 0.2,
    stratify = y,
    random_state = 42
)
model = XGBClassifier(
    random_state = 42,
    eval_metric = "logloss"
)
#MODEL TRAINING
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test ,y_pred)
auc = roc_auc_score(y_test, y_prob)
print("accuracy:", accuracy)
print("precision:", precision)
print("recall:", recall)
print("AUCROC", auc)
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# accuracy: 0.9623893805309734
# precision: 0.9183673469387755
# recall: 0.6284916201117319
# AUCROC 0.9385452273035281
# [[3690   20]
#  [ 133  225]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3710
#            1       0.92      0.63      0.75       358
#
#     accuracy                           0.96      4068
#    macro avg       0.94      0.81      0.86      4068
# weighted avg       0.96      0.96      0.96      4068
